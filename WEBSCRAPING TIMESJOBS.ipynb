# %%
from bs4 import BeautifulSoup
import requests
import time

# %%
html_text=requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation=').text

# %%
#This is without writing .text in the above htm_text
print(html_text)
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(html_text,'lxml')

# %%
#Prints all first page jobs in the list factor
jobs=soup.find_all('li',class_="clearfix job-bx wht-shd-bx")
print(jobs)
# Out:
# [<li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/python-developer-seven-consultancy-navi-mumbai-mumbai-4-to-7-yrs-jobid-uB9apavYEX9zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70428623','python  ,  mvc  ,  sql','Navi Mumbai,  Mumbai','4 - 7','IT Software : Software Products &amp; Services','1','' )" target="_blank">
# <strong class="blkclor">Python</strong> Developer</a> </h2>
# <h3 class="joblist-comp-name">
#     SEVEN CONSULTANCY
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>4 - 7 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Navi Mumbai,  Mumbai">Navi Mumbai,  Mumbai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# ...

# %%
#Looking for a job in jobs , skills required and Published Date
for job in jobs:
    company_name=job.find('h3',class_="joblist-comp-name").text.strip()
    skills=job.find('span',class_="srp-skills").text.strip().replace(' ','')
    published_date=job.find('span',class_="sim-posted").span.text
    
    print(f"""
   Company Name:{company_name}
   Required Skills:{skills}
   Published Date={published_date}
   """)
# Out:
#    Company Name:SEVEN CONSULTANCY
#    Required Skills:python,mvc,sql
#    Published Date=Posted 1 day ago
#
#
#    Company Name:Doodleblue Innovations Pvt Ltd
#    Required Skills:python,database,django,git,html5,debugging,javascript,jquery
#    Published Date=Posted 1 day ago
#
#
#    Company Name:virtusa consulting services pvt. ltd.
#    Required Skills:python,aws,flask,mysql,splunk,restapi,nosql,iam
#    Published Date=Posted 2 days ago
#
#
#    Company Name:virtusa consulting services pvt. ltd.
#    Required Skills:pythondevelopment,frameworkproficiency,applicationmigration,databasemanagement,cloudtechnologies,jobposting
#    Published Date=Posted 3 days ago
#
#
#    Company Name:virtusa consulting services pvt. ltd.
#    Required Skills:pythondevelopment,fullstackdevelopment,databasemanagement,financialservices,continuousintegration,oracle,windows,linux,softwareengineer,webdevelopment,mongodb
#    Published Date=Posted 1 day ago
#
#
# ...

# %%
#Looking for a job in jobs, skills required and an if statement of few days in the published date
for job in jobs:
     published_date=job.find('span',class_="sim-posted").span.text
     if 'few' in published_date:
        company_name=job.find('h3',class_="joblist-comp-name").text.strip()
        skills=job.find('span',class_="srp-skills").text.strip().replace(' ','')
    
        print(f"""
         Company Name:{company_name}
         Required Skills:{skills}
         Publishe Date:{published_date}
         """)
# Out:
#          Company Name:Infostretch Solution Pvt Ltd
#          Required Skills:pythondevelopment,clouddeployment,datastructures,devopsculture,unittesting,apache,java,softwareengineering,api,mq,nosql,messaging,fundamentals,storage,database,pythonscripting,git,mongodb,cloudservices,mobile,infrastructure
#          Publishe Date:Posted few days ago
#
#
#          Company Name:Advaiya Solutions Pvt Ltd
#          Required Skills:pythondevelopment,djangoframework,restapis,unittesting,designpatterns,docker,database,debugging,webdevelopment,mysql
#          Publishe Date:Posted few days ago
#
#
#          Company Name:kelly outsourcing
#          Required Skills:pythonprogramming,stremlitdevelopment,llm,generativeai,deeplearning,algorithms,c,java,debugging,softwareengineering,hadoop,bigdata,naturallanguageprocessing,machinelearning
#          Publishe Date:Posted few days ago

# %%
#Prints the first job in the list
job=soup.find('li',class_="clearfix job-bx wht-shd-bx")
print(job)
# Out:
# <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/python-developer-seven-consultancy-navi-mumbai-mumbai-4-to-7-yrs-jobid-uB9apavYEX9zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70428623','python  ,  mvc  ,  sql','Navi Mumbai,  Mumbai','4 - 7','IT Software : Software Products &amp; Services','1','' )" target="_blank">
# <strong class="blkclor">Python</strong> Developer</a> </h2>
# <h3 class="joblist-comp-name">
#     SEVEN CONSULTANCY
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>4 - 7 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Navi Mumbai,  Mumbai">Navi Mumbai,  Mumbai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# ...

# %%
company_name=job.find('h3',class_="joblist-comp-name").text.strip()
company_name
# Out:
# 'SEVEN CONSULTANCY'

# %%
skills=job.find('span',class_="srp-skills").text.strip().replace(' ','')
skills
# Out:
# 'python,mvc,sql'

# %%
published_date=job.find('span',class_="sim-posted").text.strip()
published_date
# Out:
# 'Posted 1 day ago'

# %%
print(f"""
   Company Name:{company_name}
   Required Skills:{skills}
   Published Date:{published_date}
""")
# Out:
#    Company Name:kelly outsourcing
#    Required Skills:python,mvc,sql
#    Published Date:Posted 1 day ago

# %%
job_posts=job.find('span',class_="sim-posted").text.strip()
job_posts
# Out:
# 'Posted 1 day ago'

# %%
print('Put some skill that you are not familiar with')
unfamiliar_skill=input('>')
print(f'Filtering Out {unfamiliar_skill}')
# Out:
# Put some skill that you are not familiar with
# >linux
# Filtering Out linux

# %%
def find_jobs():
    html_text=requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation=').text
    soup=BeautifulSoup(html_text,'lxml')
    jobs=soup.find_all('li',class_="clearfix job-bx wht-shd-bx")
    for job in jobs:
        published_date=job.find('span',class_="sim-posted").span.text
        if 'few' in published_date:
            company_name=job.find('h3',class_="joblist-comp-name").text.strip()
            skills=job.find('span',class_="srp-skills").text.strip().replace(' ','')
            more_info=job.header.h2.a['href']
            if unfamiliar_skill not in skills:
                print(f" Company Name: {company_name}")
        
                print(f" Skills Required: {skills}")
        
                print(f" More info: {more_info}")
                
                print(' ')

# %%
if __name__=='__main__':
    while True:
        find_jobs()
        time_wait=10
        print(f' Waiting {time_wait} minutes...' )
        time.sleep(time_wait * 60)
